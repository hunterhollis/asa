# %%
from creds import api_key
import requests
from pprint import pprint
import pandas as pd
from helper_functions import apiSports

# %% [markdown]
# ### API Set-Up and Status

# %%
nba = apiSports(api_key, 'basketball', 'v1')
response = nba.request({}, 'status')
pprint(response)
# Out:
# {'errors': [],
#  'get': 'status',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': [],
#  'response': {'account': {'email': 'hunterhollismobile@gmail.com',
#                           'firstname': 'Hunter',
#                           'lastname': 'Hollis'},
#               'requests': {'current': 0, 'limit_day': 100},
#               'subscription': {'active': True,
#                                'end': '2025-05-16T00:00:00+00:00',
#                                'plan': 'Free'}},
#  'results': 0}

# %% [markdown]
# ### Teams

# %%
teams_payload = {'league':'12', 'season':'2024-2025'}
teams_response = nba.request(teams_payload, 'teams')
pprint(teams_response)
# Out:
# {'errors': [],
#  'get': 'teams',
#  'parameters': {'league': '12', 'season': '2024-2025'},
#  'response': [{'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 132,
#                'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                'name': 'Atlanta Hawks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 133,
#                'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                'name': 'Boston Celtics',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 134,
#                'logo': 'https://media.api-sports.io/basketball/teams/134.png',
#                'name': 'Brooklyn Nets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 135,
#                'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                'name': 'Charlotte Hornets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 136,
#                'logo': 'https://media.api-sports.io/basketball/teams/136.png',
#                'name': 'Chicago Bulls',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 137,
#                'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                'name': 'Cleveland Cavaliers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 138,
#                'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                'name': 'Dallas Mavericks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 139,
#                'logo': 'https://media.api-sports.io/basketball/teams/139.png',
#                'name': 'Denver Nuggets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 140,
#                'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                'name': 'Detroit Pistons',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 141,
#                'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                'name': 'Golden State Warriors',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 142,
#                'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                'name': 'Houston Rockets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 143,
#                'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                'name': 'Indiana Pacers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 144,
#                'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                'name': 'Los Angeles Clippers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 145,
#                'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                'name': 'Los Angeles Lakers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 146,
#                'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                'name': 'Memphis Grizzlies',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 147,
#                'logo': 'https://media.api-sports.io/basketball/teams/147.png',
#                'name': 'Miami Heat',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 148,
#                'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                'name': 'Milwaukee Bucks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 149,
#                'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                'name': 'Minnesota Timberwolves',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 150,
#                'logo': 'https://media.api-sports.io/basketball/teams/150.png',
#                'name': 'New Orleans Pelicans',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 151,
#                'logo': 'https://media.api-sports.io/basketball/teams/151.png',
#                'name': 'New York Knicks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 152,
#                'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                'name': 'Oklahoma City Thunder',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 153,
#                'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                'name': 'Orlando Magic',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 154,
#                'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                'name': 'Philadelphia 76ers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 155,
#                'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                'name': 'Phoenix Suns',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 156,
#                'logo': 'https://media.api-sports.io/basketball/teams/156.png',
#                'name': 'Portland Trail Blazers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 157,
#                'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                'name': 'Sacramento Kings',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 158,
#                'logo': 'https://media.api-sports.io/basketball/teams/158.png',
#                'name': 'San Antonio Spurs',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 159,
#                'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                'name': 'Toronto Raptors',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 160,
#                'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                'name': 'Utah Jazz',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 161,
#                'logo': 'https://media.api-sports.io/basketball/teams/161.png',
#                'name': 'Washington Wizards',
#                'nationnal': False}],
#  'results': 30}

# %%
teams_df = pd.DataFrame(teams_response['response'])
teams_df.head()
# Out:
#     id               name                                               logo  \
# 0  132      Atlanta Hawks  https://media.api-sports.io/basketball/teams/1...
# 1  133     Boston Celtics  https://media.api-sports.io/basketball/teams/1...
# 2  134      Brooklyn Nets  https://media.api-sports.io/basketball/teams/1...
# 3  135  Charlotte Hornets  https://media.api-sports.io/basketball/teams/1...
# 4  136      Chicago Bulls  https://media.api-sports.io/basketball/teams/1...
#
#    nationnal                                            country
# 0      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 1      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 2      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 3      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 4      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...

# %% [markdown]
# #### Teams Data Cleaning

# %%
teams_df_final = nba.clean('teams', teams_df)
teams_df_final.head()
# Out:
#     id               name                                               logo  \
# 0  132      Atlanta Hawks  https://media.api-sports.io/basketball/teams/1...
# 1  133     Boston Celtics  https://media.api-sports.io/basketball/teams/1...
# 2  134      Brooklyn Nets  https://media.api-sports.io/basketball/teams/1...
# 3  135  Charlotte Hornets  https://media.api-sports.io/basketball/teams/1...
# 4  136      Chicago Bulls  https://media.api-sports.io/basketball/teams/1...
#
#    national  country_id country_name
# 0     False           5          USA
# 1     False           5          USA
# 2     False           5          USA
# 3     False           5          USA
# 4     False           5          USA

# %% [markdown]
# ### Games

# %%
games_payload = {'league':'12', 'season':'2024-2025', 'timezone':'America/Chicago'}
games_response = nba.request(games_payload, 'games')
pprint(games_response)
# Out:
# {'errors': [],
#  'get': 'games',
#  'parameters': {'league': '12',
#                 'season': '2024-2025',
#                 'timezone': 'America/Chicago'},
#  'response': [{'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-22T18:30:00-05:00',
#                'id': 413874,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 151,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/151.png',
#                                   'name': 'New York Knicks'},
#                          'home': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'}},
#                'time': '18:30',
#                'timestamp': 1729639800,
#                'timezone': 'America/Chicago',
#                'venue': 'TD Garden',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-22T21:00:00-05:00',
#                'id': 413875,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'},
#                          'home': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'}},
#                'time': '21:00',
#                'timestamp': 1729648800,
#                'timezone': 'America/Chicago',
#                'venue': 'Crypto.com Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T18:00:00-05:00',
#                'id': 413876,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 140,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                                   'name': 'Detroit Pistons'}},
#                'time': '18:00',
#                'timestamp': 1729724400,
#                'timezone': 'America/Chicago',
#                'venue': 'Little Caesars Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T18:30:00-05:00',
#                'id': 413877,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 134,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/134.png',
#                                   'name': 'Brooklyn Nets'},
#                          'home': {'id': 132,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                                   'name': 'Atlanta Hawks'}},
#                'time': '18:30',
#                'timestamp': 1729726200,
#                'timezone': 'America/Chicago',
#                'venue': 'State Farm Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T18:30:00-05:00',
#                'id': 413878,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 153,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                                   'name': 'Orlando Magic'},
#                          'home': {'id': 147,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/147.png',
#                                   'name': 'Miami Heat'}},
#                'time': '18:30',
#                'timestamp': 1729726200,
#                'timezone': 'America/Chicago',
#                'venue': 'Kaseya Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T18:30:00-05:00',
#                'id': 413879,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 148,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                                   'name': 'Milwaukee Bucks'},
#                          'home': {'id': 154,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                                   'name': 'Philadelphia 76ers'}},
#                'time': '18:30',
#                'timestamp': 1729726200,
#                'timezone': 'America/Chicago',
#                'venue': 'Wells Fargo Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T18:30:00-05:00',
#                'id': 413880,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 137,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                                   'name': 'Cleveland Cavaliers'},
#                          'home': {'id': 159,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                                   'name': 'Toronto Raptors'}},
#                'time': '18:30',
#                'timestamp': 1729726200,
#                'timezone': 'America/Chicago',
#                'venue': 'Scotiabank Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T19:00:00-05:00',
#                'id': 413881,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 135,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                                   'name': 'Charlotte Hornets'},
#                          'home': {'id': 142,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                                   'name': 'Houston Rockets'}},
#                'time': '19:00',
#                'timestamp': 1729728000,
#                'timezone': 'America/Chicago',
#                'venue': 'Toyota Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T19:00:00-05:00',
#                'id': 413882,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 136,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/136.png',
#                                   'name': 'Chicago Bulls'},
#                          'home': {'id': 150,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/150.png',
#                                   'name': 'New Orleans Pelicans'}},
#                'time': '19:00',
#                'timestamp': 1729728000,
#                'timezone': 'America/Chicago',
#                'venue': 'Smoothie King Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T20:00:00-05:00',
#                'id': 413883,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'},
#                          'home': {'id': 160,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                                   'name': 'Utah Jazz'}},
#                'time': '20:00',
#                'timestamp': 1729731600,
#                'timezone': 'America/Chicago',
#                'venue': 'Delta Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T21:00:00-05:00',
#                'id': 413884,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 155,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                                   'name': 'Phoenix Suns'},
#                          'home': {'id': 144,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                                   'name': 'Los Angeles Clippers'}},
#                'time': '21:00',
#                'timestamp': 1729735200,
#                'timezone': 'America/Chicago',
#                'venue': 'Crypto.com Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-23T21:00:00-05:00',
#                'id': 413885,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 141,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                                   'name': 'Golden State Warriors'},
#                          'home': {'id': 156,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/156.png',
#                                   'name': 'Portland Trail Blazers'}},
#                'time': '21:00',
#                'timestamp': 1729735200,
#                'timezone': 'America/Chicago',
#                'venue': 'Moda Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-24T18:00:00-05:00',
#                'id': 413886,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'},
#                          'home': {'id': 161,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/161.png',
#                                   'name': 'Washington Wizards'}},
#                'time': '18:00',
#                'timestamp': 1729810800,
#                'timezone': 'America/Chicago',
#                'venue': 'Capital One Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-24T18:30:00-05:00',
#                'id': 413887,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 158,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/158.png',
#                                   'name': 'San Antonio Spurs'},
#                          'home': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'}},
#                'time': '18:30',
#                'timestamp': 1729812600,
#                'timezone': 'America/Chicago',
#                'venue': 'American Airlines Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-24T21:00:00-05:00',
#                'id': 413888,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 152,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                                   'name': 'Oklahoma City Thunder'},
#                          'home': {'id': 139,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/139.png',
#                                   'name': 'Denver Nuggets'}},
#                'time': '21:00',
#                'timestamp': 1729821600,
#                'timezone': 'America/Chicago',
#                'venue': 'Ball Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-24T21:00:00-05:00',
#                'id': 413889,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'},
#                          'home': {'id': 157,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                                   'name': 'Sacramento Kings'}},
#                'time': '21:00',
#                'timestamp': 1729821600,
#                'timezone': 'America/Chicago',
#                'venue': 'Golden',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T18:00:00-05:00',
#                'id': 413890,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 134,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/134.png',
#                                   'name': 'Brooklyn Nets'},
#                          'home': {'id': 153,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                                   'name': 'Orlando Magic'}},
#                'time': '18:00',
#                'timestamp': 1729897200,
#                'timezone': 'America/Chicago',
#                'venue': 'Kia Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T18:00:00-05:00',
#                'id': 413891,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 154,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                                   'name': 'Philadelphia 76ers'},
#                          'home': {'id': 159,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                                   'name': 'Toronto Raptors'}},
#                'time': '18:00',
#                'timestamp': 1729897200,
#                'timezone': 'America/Chicago',
#                'venue': 'Scotiabank Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T18:30:00-05:00',
#                'id': 413892,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 151,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/151.png',
#                                   'name': 'New York Knicks'}},
#                'time': '18:30',
#                'timestamp': 1729899000,
#                'timezone': 'America/Chicago',
#                'venue': 'Madison Square Garden',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T18:30:00-05:00',
#                'id': 413893,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 135,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                                   'name': 'Charlotte Hornets'},
#                          'home': {'id': 132,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                                   'name': 'Atlanta Hawks'}},
#                'time': '18:30',
#                'timestamp': 1729899000,
#                'timezone': 'America/Chicago',
#                'venue': 'State Farm Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T18:30:00-05:00',
#                'id': 413894,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 140,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                                   'name': 'Detroit Pistons'},
#                          'home': {'id': 137,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                                   'name': 'Cleveland Cavaliers'}},
#                'time': '18:30',
#                'timestamp': 1729899000,
#                'timezone': 'America/Chicago',
#                'venue': 'Rocket Mortgage FieldHouse',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T19:00:00-05:00',
#                'id': 413895,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'},
#                          'home': {'id': 142,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                                   'name': 'Houston Rockets'}},
#                'time': '19:00',
#                'timestamp': 1729900800,
#                'timezone': 'America/Chicago',
#                'venue': 'Toyota Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T19:00:00-05:00',
#                'id': 413896,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 136,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/136.png',
#                                   'name': 'Chicago Bulls'},
#                          'home': {'id': 148,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                                   'name': 'Milwaukee Bucks'}},
#                'time': '19:00',
#                'timestamp': 1729900800,
#                'timezone': 'America/Chicago',
#                'venue': 'Fiserv Forum',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T20:30:00-05:00',
#                'id': 413897,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 141,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                                   'name': 'Golden State Warriors'},
#                          'home': {'id': 160,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                                   'name': 'Utah Jazz'}},
#                'time': '20:30',
#                'timestamp': 1729906200,
#                'timezone': 'America/Chicago',
#                'venue': 'Delta Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T21:00:00-05:00',
#                'id': 413898,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 155,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                                   'name': 'Phoenix Suns'},
#                          'home': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'}},
#                'time': '21:00',
#                'timestamp': 1729908000,
#                'timezone': 'America/Chicago',
#                'venue': 'Crypto.com Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-10-25T21:00:00-05:00',
#                'id': 413899,
#                'league': {'id': 12,
# ...
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 153,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                                   'name': 'Orlando Magic'},
#                          'home': {'id': 132,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                                   'name': 'Atlanta Hawks'}},
#                'time': '12:00',
#                'timestamp': 1744563600,
#                'timezone': 'America/Chicago',
#                'venue': 'State Farm Arena',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415066,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 144,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                                   'name': 'Los Angeles Clippers'},
#                          'home': {'id': 141,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                                   'name': 'Golden State Warriors'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Chase Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415067,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 139,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/139.png',
#                                   'name': 'Denver Nuggets'},
#                          'home': {'id': 142,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                                   'name': 'Houston Rockets'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Toyota Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415068,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'},
#                          'home': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'FedExForum',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415069,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 160,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                                   'name': 'Utah Jazz'},
#                          'home': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Target Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415070,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 152,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                                   'name': 'Oklahoma City Thunder'},
#                          'home': {'id': 150,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/150.png',
#                                   'name': 'New Orleans Pelicans'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Smoothie King Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415071,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'},
#                          'home': {'id': 156,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/156.png',
#                                   'name': 'Portland Trail Blazers'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Moda Center',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415072,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 155,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                                   'name': 'Phoenix Suns'},
#                          'home': {'id': 157,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                                   'name': 'Sacramento Kings'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Golden',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2025-04-13T14:30:00-05:00',
#                'id': 415073,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2024-2025',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None},
#                           'home': {'over_time': None,
#                                    'quarter_1': None,
#                                    'quarter_2': None,
#                                    'quarter_3': None,
#                                    'quarter_4': None,
#                                    'total': None}},
#                'stage': None,
#                'status': {'long': 'Not Started', 'short': 'NS', 'timer': None},
#                'teams': {'away': {'id': 159,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                                   'name': 'Toronto Raptors'},
#                          'home': {'id': 158,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/158.png',
#                                   'name': 'San Antonio Spurs'}},
#                'time': '14:30',
#                'timestamp': 1744572600,
#                'timezone': 'America/Chicago',
#                'venue': 'Frost Bank Center',
#                'week': None}],
#  'results': 1200}

# %%
games_df = pd.DataFrame(games_response['response'])
print(len(games_df))
games_df.head(1)
# Out:
# 1200
#        id                       date   time   timestamp         timezone  \
# 0  413874  2024-10-22T18:30:00-05:00  18:30  1729639800  America/Chicago
#
#   stage  week      venue                                             status  \
# 0  None  None  TD Garden  {'long': 'Not Started', 'short': 'NS', 'timer'...
#
#                                               league  \
# 0  {'id': 12, 'name': 'NBA', 'type': 'League', 's...
#
#                                              country  \
# 0  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
#
#                                                teams  \
# 0  {'home': {'id': 133, 'name': 'Boston Celtics',...
#
#                                               scores
# 0  {'home': {'quarter_1': None, 'quarter_2': None...

# %% [markdown]
# #### Games Data Cleaning

# %%
games_df_final = nba.clean('games', games_df)
games_df_final.head()
# Out:
#        id        date   time            datetime         timezone  week  \
# 0  413874  2024-10-22  18:30 2024-10-22 18:30:00  America/Chicago  None
# 1  413875  2024-10-22  21:00 2024-10-22 21:00:00  America/Chicago  None
# 2  413876  2024-10-23  18:00 2024-10-23 18:00:00  America/Chicago  None
# 3  413877  2024-10-23  18:30 2024-10-23 18:30:00  America/Chicago  None
# 4  413878  2024-10-23  18:30 2024-10-23 18:30:00  America/Chicago  None
#
#   status  country_id country_name  league_id league_name  home_id  \
# 0     NS           5          USA         12         NBA      133
# 1     NS           5          USA         12         NBA      145
# 2     NS           5          USA         12         NBA      140
# 3     NS           5          USA         12         NBA      132
# 4     NS           5          USA         12         NBA      147
#
#             home_name  away_id               away_name home_total away_total
# 0      Boston Celtics      151         New York Knicks       None       None
# 1  Los Angeles Lakers      149  Minnesota Timberwolves       None       None
# 2     Detroit Pistons      143          Indiana Pacers       None       None
# 3       Atlanta Hawks      134           Brooklyn Nets       None       None
# 4          Miami Heat      153           Orlando Magic       None       None

# %% [markdown]
# ### DB Connection

# %%
# create postgresql connection
from sqlalchemy import create_engine
from creds import postgresql_pw

engine = create_engine(f'postgresql+psycopg2://postgres:{postgresql_pw}@localhost:5432/api_sports')

# import teams_df and games_df to new tables in api-sports db
teams_df_final.to_sql('nba_teams', con=engine, if_exists='replace', index=False)
games_df_final.to_sql('nba_games', con=engine, if_exists='replace', index=False)
# Out:
# 200
