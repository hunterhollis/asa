# %%
from creds import api_key
import requests
from pprint import pprint
import pandas as pd
from helper_functions import apiSports

# %% [markdown]
# ### API Set-Up and Status

# %%
nba = apiSports(api_key, 'basketball', 'v1')
response = nba.request({}, 'status')
pprint(response)
# Out:
# {'errors': [],
#  'get': 'status',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': [],
#  'response': {'account': {'email': 'hunterhollismobile@gmail.com',
#                           'firstname': 'Hunter',
#                           'lastname': 'Hollis'},
#               'requests': {'current': 8, 'limit_day': 100},
#               'subscription': {'active': True,
#                                'end': '2025-05-16T00:00:00+00:00',
#                                'plan': 'Free'}},
#  'results': 0}

# %% [markdown]
# ### Teams

# %%
teams_payload = {'league':'12', 'season':'2023-2024'}
teams_response = nba.request(teams_payload, 'teams')
pprint(teams_response)
# Out:
# {'errors': [],
#  'get': 'teams',
#  'parameters': {'league': '12', 'season': '2023-2024'},
#  'response': [{'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 132,
#                'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                'name': 'Atlanta Hawks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 133,
#                'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                'name': 'Boston Celtics',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 134,
#                'logo': 'https://media.api-sports.io/basketball/teams/134.png',
#                'name': 'Brooklyn Nets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 135,
#                'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                'name': 'Charlotte Hornets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 136,
#                'logo': 'https://media.api-sports.io/basketball/teams/136.png',
#                'name': 'Chicago Bulls',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 137,
#                'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                'name': 'Cleveland Cavaliers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 138,
#                'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                'name': 'Dallas Mavericks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 139,
#                'logo': 'https://media.api-sports.io/basketball/teams/139.png',
#                'name': 'Denver Nuggets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 140,
#                'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                'name': 'Detroit Pistons',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 1416,
#                'logo': 'https://media.api-sports.io/basketball/teams/1416.png',
#                'name': 'East',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 141,
#                'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                'name': 'Golden State Warriors',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 142,
#                'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                'name': 'Houston Rockets',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 143,
#                'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                'name': 'Indiana Pacers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 144,
#                'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                'name': 'Los Angeles Clippers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 145,
#                'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                'name': 'Los Angeles Lakers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 146,
#                'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                'name': 'Memphis Grizzlies',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 147,
#                'logo': 'https://media.api-sports.io/basketball/teams/147.png',
#                'name': 'Miami Heat',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 148,
#                'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                'name': 'Milwaukee Bucks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 149,
#                'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                'name': 'Minnesota Timberwolves',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 150,
#                'logo': 'https://media.api-sports.io/basketball/teams/150.png',
#                'name': 'New Orleans Pelicans',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 151,
#                'logo': 'https://media.api-sports.io/basketball/teams/151.png',
#                'name': 'New York Knicks',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 152,
#                'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                'name': 'Oklahoma City Thunder',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 153,
#                'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                'name': 'Orlando Magic',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 154,
#                'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                'name': 'Philadelphia 76ers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 155,
#                'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                'name': 'Phoenix Suns',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 156,
#                'logo': 'https://media.api-sports.io/basketball/teams/156.png',
#                'name': 'Portland Trail Blazers',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 157,
#                'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                'name': 'Sacramento Kings',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 158,
#                'logo': 'https://media.api-sports.io/basketball/teams/158.png',
#                'name': 'San Antonio Spurs',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 159,
#                'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                'name': 'Toronto Raptors',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 160,
#                'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                'name': 'Utah Jazz',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 161,
#                'logo': 'https://media.api-sports.io/basketball/teams/161.png',
#                'name': 'Washington Wizards',
#                'nationnal': False},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'id': 1417,
#                'logo': 'https://media.api-sports.io/basketball/teams/1417.png',
#                'name': 'West',
#                'nationnal': False}],
#  'results': 32}

# %%
teams_df = pd.DataFrame(teams_response['response'])
teams_df.head()
# Out:
#     id               name                                               logo  \
# 0  132      Atlanta Hawks  https://media.api-sports.io/basketball/teams/1...
# 1  133     Boston Celtics  https://media.api-sports.io/basketball/teams/1...
# 2  134      Brooklyn Nets  https://media.api-sports.io/basketball/teams/1...
# 3  135  Charlotte Hornets  https://media.api-sports.io/basketball/teams/1...
# 4  136      Chicago Bulls  https://media.api-sports.io/basketball/teams/1...
#
#    nationnal                                            country
# 0      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 1      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 2      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 3      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 4      False  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...

# %% [markdown]
# #### Teams Data Cleaning

# %%
teams_df_final = nba.clean('teams', teams_df)
teams_df_final.head()
# Out:
#     id               name                                               logo  \
# 0  132      Atlanta Hawks  https://media.api-sports.io/basketball/teams/1...
# 1  133     Boston Celtics  https://media.api-sports.io/basketball/teams/1...
# 2  134      Brooklyn Nets  https://media.api-sports.io/basketball/teams/1...
# 3  135  Charlotte Hornets  https://media.api-sports.io/basketball/teams/1...
# 4  136      Chicago Bulls  https://media.api-sports.io/basketball/teams/1...
#
#    national  country_id country_name
# 0     False           5          USA
# 1     False           5          USA
# 2     False           5          USA
# 3     False           5          USA
# 4     False           5          USA

# %% [markdown]
# ### Games

# %%
games_payload = {'league':'12', 'season':'2023-2024'}
games_response = nba.request(games_payload, 'games')
pprint(games_response)
# Out:
# {'errors': [],
#  'get': 'games',
#  'parameters': {'league': '12', 'season': '2023-2024'},
#  'response': [{'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-05T16:00:00+00:00',
#                'id': 372186,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 19,
#                                    'quarter_2': 30,
#                                    'quarter_3': 25,
#                                    'quarter_4': 25,
#                                    'total': 99},
#                           'home': {'over_time': None,
#                                    'quarter_1': 37,
#                                    'quarter_2': 29,
#                                    'quarter_3': 21,
#                                    'quarter_4': 24,
#                                    'total': 111}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'},
#                          'home': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'}},
#                'time': '16:00',
#                'timestamp': 1696521600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-07T16:00:00+00:00',
#                'id': 372187,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 24,
#                                    'quarter_3': 28,
#                                    'quarter_4': 23,
#                                    'total': 104},
#                           'home': {'over_time': None,
#                                    'quarter_1': 20,
#                                    'quarter_2': 23,
#                                    'quarter_3': 27,
#                                    'quarter_4': 26,
#                                    'total': 96}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'},
#                          'home': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'}},
#                'time': '16:00',
#                'timestamp': 1696694400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-08T00:30:00+00:00',
#                'id': 372188,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 23,
#                                    'quarter_2': 31,
#                                    'quarter_3': 29,
#                                    'quarter_4': 25,
#                                    'total': 108},
#                           'home': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 32,
#                                    'quarter_3': 34,
#                                    'quarter_4': 30,
#                                    'total': 125}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'},
#                          'home': {'id': 141,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/141.png',
#                                   'name': 'Golden State Warriors'}},
#                'time': '00:30',
#                'timestamp': 1696725000,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-08T17:00:00+00:00',
#                'id': 372189,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 30,
#                                    'quarter_2': 21,
#                                    'quarter_3': 31,
#                                    'quarter_4': 20,
#                                    'total': 102},
#                           'home': {'over_time': None,
#                                    'quarter_1': 21,
#                                    'quarter_2': 29,
#                                    'quarter_3': 28,
#                                    'quarter_4': 27,
#                                    'total': 105}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 136,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/136.png',
#                                   'name': 'Chicago Bulls'},
#                          'home': {'id': 148,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                                   'name': 'Milwaukee Bucks'}},
#                'time': '17:00',
#                'timestamp': 1696784400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-08T19:00:00+00:00',
#                'id': 372190,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': 8,
#                                    'quarter_1': 46,
#                                    'quarter_2': 24,
#                                    'quarter_3': 34,
#                                    'quarter_4': 18,
#                                    'total': 130},
#                           'home': {'over_time': 4,
#                                    'quarter_1': 29,
#                                    'quarter_2': 30,
#                                    'quarter_3': 25,
#                                    'quarter_4': 38,
#                                    'total': 126}},
#                'stage': None,
#                'status': {'long': 'After Over Time',
#                           'short': 'AOT',
#                           'timer': None},
#                'teams': {'away': {'id': 155,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                                   'name': 'Phoenix Suns'},
#                          'home': {'id': 140,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                                   'name': 'Detroit Pistons'}},
#                'time': '19:00',
#                'timestamp': 1696791600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-08T22:00:00+00:00',
#                'id': 372191,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 28,
#                                    'quarter_3': 23,
#                                    'quarter_4': 26,
#                                    'total': 106},
#                           'home': {'over_time': None,
#                                    'quarter_1': 20,
#                                    'quarter_2': 39,
#                                    'quarter_3': 22,
#                                    'quarter_4': 33,
#                                    'total': 114}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 154,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                                   'name': 'Philadelphia 76ers'},
#                          'home': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'}},
#                'time': '22:00',
#                'timestamp': 1696802400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-09T00:00:00+00:00',
#                'id': 372192,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': 8,
#                                    'quarter_1': 32,
#                                    'quarter_2': 27,
#                                    'quarter_3': 32,
#                                    'quarter_4': 23,
#                                    'total': 122},
#                           'home': {'over_time': 13,
#                                    'quarter_1': 34,
#                                    'quarter_2': 32,
#                                    'quarter_3': 25,
#                                    'quarter_4': 23,
#                                    'total': 127}},
#                'stage': None,
#                'status': {'long': 'After Over Time',
#                           'short': 'AOT',
#                           'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'}},
#                'time': '00:00',
#                'timestamp': 1696809600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-09T00:00:00+00:00',
#                'id': 372193,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 35,
#                                    'quarter_2': 20,
#                                    'quarter_3': 19,
#                                    'quarter_4': 25,
#                                    'total': 99},
#                           'home': {'over_time': None,
#                                    'quarter_1': 35,
#                                    'quarter_2': 34,
#                                    'quarter_3': 26,
#                                    'quarter_4': 17,
#                                    'total': 112}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 157,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                                   'name': 'Sacramento Kings'},
#                          'home': {'id': 159,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/159.png',
#                                   'name': 'Toronto Raptors'}},
#                'time': '00:00',
#                'timestamp': 1696809600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-09T01:00:00+00:00',
#                'id': 372194,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 24,
#                                    'quarter_2': 19,
#                                    'quarter_3': 26,
#                                    'quarter_4': 32,
#                                    'total': 101},
#                           'home': {'over_time': None,
#                                    'quarter_1': 27,
#                                    'quarter_2': 23,
#                                    'quarter_3': 16,
#                                    'quarter_4': 30,
#                                    'total': 96}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 160,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                                   'name': 'Utah Jazz'},
#                          'home': {'id': 144,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                                   'name': 'Los Angeles Clippers'}},
#                'time': '01:00',
#                'timestamp': 1696813200,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-09T23:30:00+00:00',
#                'id': 372195,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 22,
#                                    'quarter_3': 34,
#                                    'quarter_4': 22,
#                                    'total': 107},
#                           'home': {'over_time': None,
#                                    'quarter_1': 28,
#                                    'quarter_2': 29,
#                                    'quarter_3': 34,
#                                    'quarter_4': 23,
#                                    'total': 114}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'},
#                          'home': {'id': 151,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/151.png',
#                                   'name': 'New York Knicks'}},
#                'time': '23:30',
#                'timestamp': 1696894200,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-10T00:00:00+00:00',
#                'id': 372196,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 43,
#                                    'quarter_2': 38,
#                                    'quarter_3': 17,
#                                    'quarter_4': 23,
#                                    'total': 121},
#                           'home': {'over_time': None,
#                                    'quarter_1': 30,
#                                    'quarter_2': 44,
#                                    'quarter_3': 30,
#                                    'quarter_4': 18,
#                                    'total': 122}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 158,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/158.png',
#                                   'name': 'San Antonio Spurs'},
#                          'home': {'id': 152,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                                   'name': 'Oklahoma City Thunder'}},
#                'time': '00:00',
#                'timestamp': 1696896000,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-10T01:00:00+00:00',
#                'id': 372197,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 35,
#                                    'quarter_2': 26,
#                                    'quarter_3': 41,
#                                    'quarter_4': 24,
#                                    'total': 126},
#                           'home': {'over_time': None,
#                                    'quarter_1': 34,
#                                    'quarter_2': 41,
#                                    'quarter_3': 35,
#                                    'quarter_4': 19,
#                                    'total': 129}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 134,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/134.png',
#                                   'name': 'Brooklyn Nets'},
#                          'home': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'}},
#                'time': '01:00',
#                'timestamp': 1696899600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-10T23:30:00+00:00',
#                'id': 372198,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 25,
#                                    'quarter_2': 20,
#                                    'quarter_3': 35,
#                                    'quarter_4': 27,
#                                    'total': 107},
#                           'home': {'over_time': None,
#                                    'quarter_1': 26,
#                                    'quarter_2': 31,
#                                    'quarter_3': 20,
#                                    'quarter_4': 31,
#                                    'total': 108}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 137,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                                   'name': 'Cleveland Cavaliers'},
#                          'home': {'id': 132,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                                   'name': 'Atlanta Hawks'}},
#                'time': '23:30',
#                'timestamp': 1696980600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-10T23:30:00+00:00',
#                'id': 372199,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 22,
#                                    'quarter_2': 30,
#                                    'quarter_3': 28,
#                                    'quarter_4': 29,
#                                    'total': 109},
#                           'home': {'over_time': None,
#                                    'quarter_1': 25,
#                                    'quarter_2': 28,
#                                    'quarter_3': 25,
#                                    'quarter_4': 35,
#                                    'total': 113}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 135,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                                   'name': 'Charlotte Hornets'},
#                          'home': {'id': 147,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/147.png',
#                                   'name': 'Miami Heat'}},
#                'time': '23:30',
#                'timestamp': 1696980600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T00:00:00+00:00',
#                'id': 372200,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 24,
#                                    'quarter_3': 25,
#                                    'quarter_4': 23,
#                                    'total': 103},
#                           'home': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 31,
#                                    'quarter_3': 26,
#                                    'quarter_4': 36,
#                                    'total': 122}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 142,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/142.png',
#                                   'name': 'Houston Rockets'}},
#                'time': '00:00',
#                'timestamp': 1696982400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T00:00:00+00:00',
#                'id': 372201,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 28,
#                                    'quarter_2': 25,
#                                    'quarter_3': 18,
#                                    'quarter_4': 31,
#                                    'total': 102},
#                           'home': {'over_time': None,
#                                    'quarter_1': 25,
#                                    'quarter_2': 26,
#                                    'quarter_3': 25,
#                                    'quarter_4': 32,
#                                    'total': 108}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 148,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/148.png',
#                                   'name': 'Milwaukee Bucks'},
#                          'home': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'}},
#                'time': '00:00',
#                'timestamp': 1696982400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T00:00:00+00:00',
#                'id': 372202,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 26,
#                                    'quarter_2': 41,
#                                    'quarter_3': 21,
#                                    'quarter_4': 34,
#                                    'total': 122},
#                           'home': {'over_time': None,
#                                    'quarter_1': 38,
#                                    'quarter_2': 30,
#                                    'quarter_3': 19,
#                                    'quarter_4': 18,
#                                    'total': 105}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 153,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                                   'name': 'Orlando Magic'},
#                          'home': {'id': 150,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/150.png',
#                                   'name': 'New Orleans Pelicans'}},
#                'time': '00:00',
#                'timestamp': 1696982400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T02:00:00+00:00',
#                'id': 372203,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 21,
#                                    'quarter_2': 18,
#                                    'quarter_3': 30,
#                                    'quarter_4': 29,
#                                    'total': 98},
#                           'home': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 20,
#                                    'quarter_3': 23,
#                                    'quarter_4': 31,
#                                    'total': 103}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 160,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/160.png',
#                                   'name': 'Utah Jazz'},
#                          'home': {'id': 144,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/144.png',
#                                   'name': 'Los Angeles Clippers'}},
#                'time': '02:00',
#                'timestamp': 1696989600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T02:00:00+00:00',
#                'id': 372204,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 25,
#                                    'quarter_2': 30,
#                                    'quarter_3': 32,
#                                    'quarter_4': 28,
#                                    'total': 115},
#                           'home': {'over_time': None,
#                                    'quarter_1': 23,
#                                    'quarter_2': 25,
#                                    'quarter_3': 29,
#                                    'quarter_4': 30,
#                                    'total': 107}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 139,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/139.png',
#                                   'name': 'Denver Nuggets'},
#                          'home': {'id': 155,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/155.png',
#                                   'name': 'Phoenix Suns'}},
#                'time': '02:00',
#                'timestamp': 1696989600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-11T23:00:00+00:00',
#                'id': 372205,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 35,
#                                    'quarter_2': 32,
#                                    'quarter_3': 23,
#                                    'quarter_4': 22,
#                                    'total': 112},
#                           'home': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 28,
#                                    'quarter_3': 16,
#                                    'quarter_4': 26,
#                                    'total': 101}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'},
#                          'home': {'id': 154,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/154.png',
#                                   'name': 'Philadelphia 76ers'}},
#                'time': '23:00',
#                'timestamp': 1697065200,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-12T02:00:00+00:00',
#                'id': 372206,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 28,
#                                    'quarter_2': 23,
#                                    'quarter_3': 28,
#                                    'quarter_4': 22,
#                                    'total': 101},
#                           'home': {'over_time': None,
#                                    'quarter_1': 30,
#                                    'quarter_2': 20,
#                                    'quarter_3': 40,
#                                    'quarter_4': 19,
#                                    'total': 109}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 157,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/157.png',
#                                   'name': 'Sacramento Kings'},
#                          'home': {'id': 145,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/145.png',
#                                   'name': 'Los Angeles Lakers'}},
#                'time': '02:00',
#                'timestamp': 1697076000,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-12T23:00:00+00:00',
#                'id': 372207,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 32,
#                                    'quarter_3': 25,
#                                    'quarter_4': 20,
#                                    'total': 108},
#                           'home': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 20,
#                                    'quarter_3': 25,
#                                    'quarter_4': 29,
#                                    'total': 105}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 153,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/153.png',
#                                   'name': 'Orlando Magic'},
#                          'home': {'id': 137,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/137.png',
#                                   'name': 'Cleveland Cavaliers'}},
#                'time': '23:00',
#                'timestamp': 1697151600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-12T23:00:00+00:00',
#                'id': 372208,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 28,
#                                    'quarter_2': 30,
#                                    'quarter_3': 32,
#                                    'quarter_4': 38,
#                                    'total': 128},
#                           'home': {'over_time': None,
#                                    'quarter_1': 34,
#                                    'quarter_2': 40,
#                                    'quarter_3': 28,
#                                    'quarter_4': 23,
#                                    'total': 125}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 140,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/140.png',
#                                   'name': 'Detroit Pistons'},
#                          'home': {'id': 152,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/152.png',
#                                   'name': 'Oklahoma City Thunder'}},
#                'time': '23:00',
#                'timestamp': 1697151600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-12T23:00:00+00:00',
#                'id': 372209,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 30,
#                                    'quarter_2': 22,
#                                    'quarter_3': 23,
#                                    'quarter_4': 17,
#                                    'total': 92},
#                           'home': {'over_time': None,
#                                    'quarter_1': 23,
#                                    'quarter_2': 22,
#                                    'quarter_3': 18,
#                                    'quarter_4': 35,
#                                    'total': 98}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 135,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/135.png',
#                                   'name': 'Charlotte Hornets'},
#                          'home': {'id': 161,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/161.png',
#                                   'name': 'Washington Wizards'}},
#                'time': '23:00',
#                'timestamp': 1697151600,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-12T23:30:00+00:00',
#                'id': 372210,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 19,
#                                    'quarter_3': 23,
#                                    'quarter_4': 29,
#                                    'total': 102},
#                           'home': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 30,
#                                    'quarter_3': 25,
#                                    'quarter_4': 19,
#                                    'total': 103}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 146,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/146.png',
#                                   'name': 'Memphis Grizzlies'},
#                          'home': {'id': 132,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/132.png',
#                                   'name': 'Atlanta Hawks'}},
#                'time': '23:30',
#                'timestamp': 1697153400,
#                'timezone': 'UTC',
#                'week': None},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2023-10-13T00:00:00+00:00',
#                'id': 372211,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': 12,
#                                    'quarter_1': 33,
#                                    'quarter_2': 23,
#                                    'quarter_3': 23,
#                                    'quarter_4': 33,
#                                    'total': 124},
#                           'home': {'over_time': 21,
# ...
#                                    'total': 133}},
#                'stage': None,
#                'status': {'long': 'After Over Time',
#                           'short': 'AOT',
#                           'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'}},
#                'time': '00:00',
#                'timestamp': 1716336000,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-23T00:30:00+00:00',
#                'id': 399497,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 27,
#                                    'quarter_2': 32,
#                                    'quarter_3': 23,
#                                    'quarter_4': 26,
#                                    'total': 108},
#                           'home': {'over_time': None,
#                                    'quarter_1': 33,
#                                    'quarter_2': 29,
#                                    'quarter_3': 21,
#                                    'quarter_4': 22,
#                                    'total': 105}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'},
#                          'home': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'}},
#                'time': '00:30',
#                'timestamp': 1716424200,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-24T00:00:00+00:00',
#                'id': 399498,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 27,
#                                    'quarter_2': 24,
#                                    'quarter_3': 29,
#                                    'quarter_4': 30,
#                                    'total': 110},
#                           'home': {'over_time': None,
#                                    'quarter_1': 25,
#                                    'quarter_2': 32,
#                                    'quarter_3': 36,
#                                    'quarter_4': 33,
#                                    'total': 126}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'},
#                          'home': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'}},
#                'time': '00:00',
#                'timestamp': 1716508800,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-25T00:30:00+00:00',
#                'id': 399499,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 26,
#                                    'quarter_2': 22,
#                                    'quarter_3': 31,
#                                    'quarter_4': 30,
#                                    'total': 109},
#                           'home': {'over_time': None,
#                                    'quarter_1': 32,
#                                    'quarter_2': 28,
#                                    'quarter_3': 26,
#                                    'quarter_4': 22,
#                                    'total': 108}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'},
#                          'home': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'}},
#                'time': '00:30',
#                'timestamp': 1716597000,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-26T00:30:00+00:00',
#                'id': 399500,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 32,
#                                    'quarter_2': 25,
#                                    'quarter_3': 24,
#                                    'quarter_4': 33,
#                                    'total': 114},
#                           'home': {'over_time': None,
#                                    'quarter_1': 31,
#                                    'quarter_2': 38,
#                                    'quarter_3': 21,
#                                    'quarter_4': 21,
#                                    'total': 111}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'},
#                          'home': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'}},
#                'time': '00:30',
#                'timestamp': 1716683400,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-27T00:00:00+00:00',
#                'id': 399501,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 28,
#                                    'quarter_2': 24,
#                                    'quarter_3': 35,
#                                    'quarter_4': 20,
#                                    'total': 107},
#                           'home': {'over_time': None,
#                                    'quarter_1': 33,
#                                    'quarter_2': 27,
#                                    'quarter_3': 27,
#                                    'quarter_4': 29,
#                                    'total': 116}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'},
#                          'home': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'}},
#                'time': '00:00',
#                'timestamp': 1716768000,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-28T00:00:00+00:00',
#                'id': 399502,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 29,
#                                    'quarter_2': 29,
#                                    'quarter_3': 22,
#                                    'quarter_4': 25,
#                                    'total': 105},
#                           'home': {'over_time': None,
#                                    'quarter_1': 27,
#                                    'quarter_2': 30,
#                                    'quarter_3': 26,
#                                    'quarter_4': 19,
#                                    'total': 102}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 133,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/133.png',
#                                   'name': 'Boston Celtics'},
#                          'home': {'id': 143,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/143.png',
#                                   'name': 'Indiana Pacers'}},
#                'time': '00:00',
#                'timestamp': 1716854400,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-29T00:30:00+00:00',
#                'id': 399503,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 27,
#                                    'quarter_2': 22,
#                                    'quarter_3': 29,
#                                    'quarter_4': 27,
#                                    'total': 105},
#                           'home': {'over_time': None,
#                                    'quarter_1': 20,
#                                    'quarter_2': 29,
#                                    'quarter_3': 24,
#                                    'quarter_4': 27,
#                                    'total': 100}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'},
#                          'home': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'}},
#                'time': '00:30',
#                'timestamp': 1716942600,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'},
#               {'country': {'code': 'US',
#                            'flag': 'https://media.api-sports.io/flags/us.svg',
#                            'id': 5,
#                            'name': 'USA'},
#                'date': '2024-05-31T00:30:00+00:00',
#                'id': 399809,
#                'league': {'id': 12,
#                           'logo': 'https://media.api-sports.io/basketball/leagues/12.png',
#                           'name': 'NBA',
#                           'season': '2023-2024',
#                           'type': 'League'},
#                'scores': {'away': {'over_time': None,
#                                    'quarter_1': 35,
#                                    'quarter_2': 34,
#                                    'quarter_3': 28,
#                                    'quarter_4': 27,
#                                    'total': 124},
#                           'home': {'over_time': None,
#                                    'quarter_1': 19,
#                                    'quarter_2': 21,
#                                    'quarter_3': 33,
#                                    'quarter_4': 30,
#                                    'total': 103}},
#                'stage': None,
#                'status': {'long': 'Game Finished',
#                           'short': 'FT',
#                           'timer': None},
#                'teams': {'away': {'id': 138,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/138.png',
#                                   'name': 'Dallas Mavericks'},
#                          'home': {'id': 149,
#                                   'logo': 'https://media.api-sports.io/basketball/teams/149.png',
#                                   'name': 'Minnesota Timberwolves'}},
#                'time': '00:30',
#                'timestamp': 1717115400,
#                'timezone': 'UTC',
#                'week': 'NBA - Semi-finals'}],
#  'results': 1372}

# %%
games_df = pd.DataFrame(games_response['response'])
print(len(games_df))
games_df.head(1)
# Out:
# 1372
#        id                       date   time   timestamp timezone stage  week  \
# 0  372186  2023-10-05T16:00:00+00:00  16:00  1696521600      UTC  None  None
#
#                                               status  \
# 0  {'long': 'Game Finished', 'short': 'FT', 'time...
#
#                                               league  \
# 0  {'id': 12, 'name': 'NBA', 'type': 'League', 's...
#
#                                              country  \
# 0  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
#
#                                                teams  \
# 0  {'home': {'id': 149, 'name': 'Minnesota Timber...
#
#                                               scores
# 0  {'home': {'quarter_1': 37, 'quarter_2': 29, 'q...

# %% [markdown]
# #### Games Data Cleaning

# %%
games_df_final = nba.clean('games', games_df)
games_df_final.head()
# Out:
#        id        date   time                  datetime timezone  week status  \
# 0  372186  2023-10-05  16:00 2023-10-05 16:00:00+00:00      UTC  None     FT
# 1  372187  2023-10-07  16:00 2023-10-07 16:00:00+00:00      UTC  None     FT
# 2  372188  2023-10-08  00:30 2023-10-08 00:30:00+00:00      UTC  None     FT
# 3  372189  2023-10-08  17:00 2023-10-08 17:00:00+00:00      UTC  None     FT
# 4  372190  2023-10-08  19:00 2023-10-08 19:00:00+00:00      UTC  None    AOT
#
#    country_id country_name  league_id league_name  home_id  \
# 0           5          USA         12         NBA      149
# 1           5          USA         12         NBA      138
# 2           5          USA         12         NBA      141
# 3           5          USA         12         NBA      148
# 4           5          USA         12         NBA      140
#
#                 home_name  away_id               away_name  home_total  \
# 0  Minnesota Timberwolves      138        Dallas Mavericks         111
# 1        Dallas Mavericks      149  Minnesota Timberwolves          96
# 2   Golden State Warriors      145      Los Angeles Lakers         125
# 3         Milwaukee Bucks      136           Chicago Bulls         105
# 4         Detroit Pistons      155            Phoenix Suns         126
#
#    away_total
# 0          99
# 1         104
# 2         108
# 3         102
# 4         130

# %% [markdown]
# ### DB Connection

# %%
# create postgresql connection
from sqlalchemy import create_engine
from creds import postgresql_pw

engine = create_engine(f'postgresql+psycopg2://postgres:{postgresql_pw}@localhost:5432/api_sports')

# import teams_df and games_df to new tables in api-sports db
teams_df_final.to_sql('nba_teams', con=engine, if_exists='replace', index=False)
games_df_final.to_sql('nba_games', con=engine, if_exists='replace', index=False)
# Out:
# 372
