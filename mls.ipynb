# %%
from creds import api_key
import requests
from pprint import pprint
import pandas as pd
from helper_functions import apiSports

# %% [markdown]
# ### API Set-Up and Status

# %%
mls = apiSports(api_key, 'football', 'v3')
response = mls.request({}, 'status')
pprint(response)
# Out:
# {'errors': [],
#  'get': 'status',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': [],
#  'response': {'account': {'email': 'hunterhollismobile@gmail.com',
#                           'firstname': 'Hunter',
#                           'lastname': 'Hollis'},
#               'requests': {'current': 0, 'limit_day': 100},
#               'subscription': {'active': True,
#                                'end': '2025-05-16T00:00:00+00:00',
#                                'plan': 'Free'}},
#  'results': 0}

# %% [markdown]
# ### Teams

# %%
teams_payload = {'league':'253', 'season':'2024'}
teams_response = mls.request(teams_payload, 'teams')
pprint(teams_response)
# Out:
# {'errors': [],
#  'get': 'teams',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'league': '253', 'season': '2024'},
#  'response': [{'team': {'code': 'SEA',
#                         'country': 'USA',
#                         'founded': 2007,
#                         'id': 1595,
#                         'logo': 'https://media.api-sports.io/football/teams/1595.png',
#                         'name': 'Seattle Sounders',
#                         'national': False},
#                'venue': {'address': '800 Occidental Avenue South',
#                          'capacity': 72000,
#                          'city': 'Seattle, Washington',
#                          'id': 11534,
#                          'image': 'https://media.api-sports.io/football/venues/11534.png',
#                          'name': 'Lumen Field',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': 'JOS',
#                         'country': 'USA',
#                         'founded': 1995,
#                         'id': 1596,
#                         'logo': 'https://media.api-sports.io/football/teams/1596.png',
#                         'name': 'San Jose Earthquakes',
#                         'national': False},
#                'venue': {'address': '1123 Coleman Avenue',
#                          'capacity': 18000,
#                          'city': 'San Jose, California',
#                          'id': 11918,
#                          'image': 'https://media.api-sports.io/football/venues/11918.png',
#                          'name': 'PayPal Park',
#                          'surface': 'grass'}},
#               {'team': {'code': 'DAL',
#                         'country': 'USA',
#                         'founded': 1996,
#                         'id': 1597,
#                         'logo': 'https://media.api-sports.io/football/teams/1597.png',
#                         'name': 'FC Dallas',
#                         'national': False},
#                'venue': {'address': '6000 Main Street',
#                          'capacity': 22565,
#                          'city': 'Frisco, Texas',
#                          'id': 1612,
#                          'image': 'https://media.api-sports.io/football/venues/1612.png',
#                          'name': 'Toyota Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2008,
#                         'id': 1598,
#                         'logo': 'https://media.api-sports.io/football/teams/1598.png',
#                         'name': 'Orlando City SC',
#                         'national': False},
#                'venue': {'address': '655 West Church Street',
#                          'capacity': 25527,
#                          'city': 'Orlando, Florida',
#                          'id': 20500,
#                          'image': 'https://media.api-sports.io/football/venues/20500.png',
#                          'name': 'Inter&Co Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': 'PHI',
#                         'country': 'USA',
#                         'founded': None,
#                         'id': 1599,
#                         'logo': 'https://media.api-sports.io/football/teams/1599.png',
#                         'name': 'Philadelphia Union',
#                         'national': False},
#                'venue': {'address': '1 Lower State Road',
#                          'capacity': 1000,
#                          'city': 'North Wales, Pennsylvania',
#                          'id': 20745,
#                          'image': 'https://media.api-sports.io/football/venues/20745.png',
#                          'name': 'Ukrainian American Sport Center',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': 'HOU',
#                         'country': 'USA',
#                         'founded': 2005,
#                         'id': 1600,
#                         'logo': 'https://media.api-sports.io/football/teams/1600.png',
#                         'name': 'Houston Dynamo',
#                         'national': False},
#                'venue': {'address': '2200 Texas Avenue, East End',
#                          'capacity': 22661,
#                          'city': 'Houston, Texas',
#                          'id': 19418,
#                          'image': 'https://media.api-sports.io/football/venues/19418.png',
#                          'name': 'Shell Energy Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': 'TOR',
#                         'country': 'Canada',
#                         'founded': 2006,
#                         'id': 1601,
#                         'logo': 'https://media.api-sports.io/football/teams/1601.png',
#                         'name': 'Toronto FC',
#                         'national': False},
#                'venue': {'address': '170 Princes’ Boulevard',
#                          'capacity': 36045,
#                          'city': 'Toronto, Ontario',
#                          'id': 312,
#                          'image': 'https://media.api-sports.io/football/venues/312.png',
#                          'name': 'BMO Field',
#                          'surface': 'grass'}},
#               {'team': {'code': 'YOR',
#                         'country': 'USA',
#                         'founded': 1995,
#                         'id': 1602,
#                         'logo': 'https://media.api-sports.io/football/teams/1602.png',
#                         'name': 'New York Red Bulls',
#                         'national': False},
#                'venue': {'address': 'Frank Rogers Boulevard South',
#                          'capacity': 26765,
#                          'city': 'Harrison, New Jersey',
#                          'id': 1619,
#                          'image': 'https://media.api-sports.io/football/venues/1619.png',
#                          'name': 'Red Bull Arena',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'Canada',
#                         'founded': 1986,
#                         'id': 1603,
#                         'logo': 'https://media.api-sports.io/football/teams/1603.png',
#                         'name': 'Vancouver Whitecaps',
#                         'national': False},
#                'venue': {'address': '777 Pacific Boulevard, False Creek',
#                          'capacity': 54405,
#                          'city': 'Vancouver, British Columbia',
#                          'id': 19445,
#                          'image': 'https://media.api-sports.io/football/venues/19445.png',
#                          'name': 'BC Place',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2013,
#                         'id': 1604,
#                         'logo': 'https://media.api-sports.io/football/teams/1604.png',
#                         'name': 'New York City FC',
#                         'national': False},
#                'venue': {'address': 'One East 161st Street, The Bronx',
#                          'capacity': 54251,
#                          'city': 'New York City',
#                          'id': 1833,
#                          'image': 'https://media.api-sports.io/football/venues/1833.png',
#                          'name': 'Yankee Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': 'ANG',
#                         'country': 'USA',
#                         'founded': 1995,
#                         'id': 1605,
#                         'logo': 'https://media.api-sports.io/football/teams/1605.png',
#                         'name': 'Los Angeles Galaxy',
#                         'national': False},
#                'venue': {'address': '18400 Avalon Boulevard, Dominguez Hills',
#                          'capacity': 30510,
#                          'city': 'Carson, California',
#                          'id': 1616,
#                          'image': 'https://media.api-sports.io/football/venues/1616.png',
#                          'name': 'Dignity Health Sports Park',
#                          'surface': 'grass'}},
#               {'team': {'code': 'SAL',
#                         'country': 'USA',
#                         'founded': 2004,
#                         'id': 1606,
#                         'logo': 'https://media.api-sports.io/football/teams/1606.png',
#                         'name': 'Real Salt Lake',
#                         'national': False},
#                'venue': {'address': '9256 South State Street',
#                          'capacity': 21810,
#                          'city': 'Sandy, Utah',
#                          'id': 19223,
#                          'image': 'https://media.api-sports.io/football/venues/19223.png',
#                          'name': 'America First Field',
#                          'surface': 'grass'}},
#               {'team': {'code': 'CHI',
#                         'country': 'USA',
#                         'founded': 1997,
#                         'id': 1607,
#                         'logo': 'https://media.api-sports.io/football/teams/1607.png',
#                         'name': 'Chicago Fire',
#                         'national': False},
#                'venue': {'address': '1410 South Museum Campus Drive',
#                          'capacity': 62493,
#                          'city': 'Chicago, Illinois',
#                          'id': 1609,
#                          'image': 'https://media.api-sports.io/football/venues/1609.png',
#                          'name': 'Soldier Field',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2014,
#                         'id': 1608,
#                         'logo': 'https://media.api-sports.io/football/teams/1608.png',
#                         'name': 'Atlanta United FC',
#                         'national': False},
#                'venue': {'address': '1 AMB Drive North West',
#                          'capacity': 73019,
#                          'city': 'Atlanta, Georgia',
#                          'id': 1898,
#                          'image': 'https://media.api-sports.io/football/venues/1898.png',
#                          'name': 'Mercedes-Benz Stadium',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': 'ENG',
#                         'country': 'USA',
#                         'founded': 1995,
#                         'id': 1609,
#                         'logo': 'https://media.api-sports.io/football/teams/1609.png',
#                         'name': 'New England Revolution',
#                         'national': False},
#                'venue': {'address': '1388 One Patriot Place',
#                          'capacity': 68756,
#                          'city': 'Foxborough, Massachusetts',
#                          'id': 1618,
#                          'image': 'https://media.api-sports.io/football/venues/1618.png',
#                          'name': 'Gillette Stadium',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': 'COL',
#                         'country': 'USA',
#                         'founded': 1996,
#                         'id': 1610,
#                         'logo': 'https://media.api-sports.io/football/teams/1610.png',
#                         'name': 'Colorado Rapids',
#                         'national': False},
#                'venue': {'address': '6000 Victory Way',
#                          'capacity': 19734,
#                          'city': 'Commerce City, Colorado',
#                          'id': 1610,
#                          'image': 'https://media.api-sports.io/football/venues/1610.png',
#                          'name': "Dick's Sporting Goods Park",
#                          'surface': 'grass'}},
#               {'team': {'code': 'KAN',
#                         'country': 'USA',
#                         'founded': 1995,
#                         'id': 1611,
#                         'logo': 'https://media.api-sports.io/football/teams/1611.png',
#                         'name': 'Sporting Kansas City',
#                         'national': False},
#                'venue': {'address': 'One Sporting Way',
#                          'capacity': 21650,
#                          'city': 'Kansas City, Kansas',
#                          'id': 1615,
#                          'image': 'https://media.api-sports.io/football/venues/1615.png',
#                          'name': "Children's Mercy Park",
#                          'surface': 'grass'}},
#               {'team': {'code': 'MIN',
#                         'country': 'USA',
#                         'founded': 2010,
#                         'id': 1612,
#                         'logo': 'https://media.api-sports.io/football/teams/1612.png',
#                         'name': 'Minnesota United FC',
#                         'national': False},
#                'venue': {'address': '400 Snelling Avenue North',
#                          'capacity': 19954,
#                          'city': 'Saint Paul, Minnesota',
#                          'id': 1617,
#                          'image': 'https://media.api-sports.io/football/venues/1617.png',
#                          'name': 'Allianz Field',
#                          'surface': 'grass'}},
#               {'team': {'code': 'COL',
#                         'country': 'USA',
#                         'founded': 1996,
#                         'id': 1613,
#                         'logo': 'https://media.api-sports.io/football/teams/1613.png',
#                         'name': 'Columbus Crew',
#                         'national': False},
#                'venue': {'address': '560 West Nationwide Boulevard',
#                          'capacity': 20927,
#                          'city': 'Columbus, Ohio',
#                          'id': 12667,
#                          'image': 'https://media.api-sports.io/football/venues/12667.png',
#                          'name': 'Lower.com Field',
#                          'surface': 'grass'}},
#               {'team': {'code': 'MON',
#                         'country': 'Canada',
#                         'founded': 2010,
#                         'id': 1614,
#                         'logo': 'https://media.api-sports.io/football/teams/1614.png',
#                         'name': 'Montreal Impact',
#                         'national': False},
#                'venue': {'address': '4750, rue Sherbrooke Est',
#                          'capacity': 20801,
#                          'city': 'Montreal, Quebec',
#                          'id': 310,
#                          'image': 'https://media.api-sports.io/football/venues/310.png',
#                          'name': 'Stade Saputo',
#                          'surface': 'grass'}},
#               {'team': {'code': 'UNI',
#                         'country': 'USA',
#                         'founded': 1996,
#                         'id': 1615,
#                         'logo': 'https://media.api-sports.io/football/teams/1615.png',
#                         'name': 'DC United',
#                         'national': False},
#                'venue': {'address': '32-60 R Street South West, Buzzard Point',
#                          'capacity': 20621,
#                          'city': 'Washington, District of Columbia',
#                          'id': 1613,
#                          'image': 'https://media.api-sports.io/football/venues/1613.png',
#                          'name': 'Audi Field',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2014,
#                         'id': 1616,
#                         'logo': 'https://media.api-sports.io/football/teams/1616.png',
#                         'name': 'Los Angeles FC',
#                         'national': False},
#                'venue': {'address': '3939 S Figueroa Street',
#                          'capacity': 22921,
#                          'city': 'Los Angeles, California',
#                          'id': 19419,
#                          'image': 'https://media.api-sports.io/football/venues/19419.png',
#                          'name': 'BMO Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': 'POR',
#                         'country': 'USA',
#                         'founded': 2009,
#                         'id': 1617,
#                         'logo': 'https://media.api-sports.io/football/teams/1617.png',
#                         'name': 'Portland Timbers',
#                         'national': False},
#                'venue': {'address': '1844 SW Morrison Street',
#                          'capacity': 25518,
#                          'city': 'Portland, Oregon',
#                          'id': 1748,
#                          'image': 'https://media.api-sports.io/football/venues/1748.png',
#                          'name': 'Providence Park',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': None,
#                         'id': 2242,
#                         'logo': 'https://media.api-sports.io/football/teams/2242.png',
#                         'name': 'FC Cincinnati',
#                         'national': False},
#                'venue': {'address': '1501 Central Parkway',
#                          'capacity': 26000,
#                          'city': 'Cincinnati, Ohio',
#                          'id': 19229,
#                          'image': 'https://media.api-sports.io/football/venues/19229.png',
#                          'name': 'TQL Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2018,
#                         'id': 9568,
#                         'logo': 'https://media.api-sports.io/football/teams/9568.png',
#                         'name': 'Inter Miami',
#                         'national': False},
#                'venue': {'address': '1350 Northwest 55th Street',
#                          'capacity': 21550,
#                          'city': 'Fort Lauderdale, Florida',
#                          'id': 20764,
#                          'image': 'https://media.api-sports.io/football/venues/20764.png',
#                          'name': 'Chase Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2020,
#                         'id': 9569,
#                         'logo': 'https://media.api-sports.io/football/teams/9569.png',
#                         'name': 'Nashville SC',
#                         'national': False},
#                'venue': {'address': '513 Benton Avenue',
#                          'capacity': 30109,
#                          'city': 'Nashville, Tennessee',
#                          'id': 19357,
#                          'image': 'https://media.api-sports.io/football/venues/19357.png',
#                          'name': 'GEODIS Park',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2021,
#                         'id': 16489,
#                         'logo': 'https://media.api-sports.io/football/teams/16489.png',
#                         'name': 'Austin',
#                         'national': False},
#                'venue': {'address': '10414 Mc Kalla Place',
#                          'capacity': 20738,
#                          'city': 'Austin, Texas',
#                          'id': 11535,
#                          'image': 'https://media.api-sports.io/football/venues/11535.png',
#                          'name': 'Q2 Stadium',
#                          'surface': 'grass'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2019,
#                         'id': 18310,
#                         'logo': 'https://media.api-sports.io/football/teams/18310.png',
#                         'name': 'Charlotte',
#                         'national': False},
#                'venue': {'address': '800 South Mint Street',
#                          'capacity': 75412,
#                          'city': 'Charlotte, North Carolina',
#                          'id': 18659,
#                          'image': 'https://media.api-sports.io/football/venues/18659.png',
#                          'name': 'Bank of America Stadium',
#                          'surface': 'artificial turf'}},
#               {'team': {'code': None,
#                         'country': 'USA',
#                         'founded': 2023,
#                         'id': 20787,
#                         'logo': 'https://media.api-sports.io/football/teams/20787.png',
#                         'name': 'St. Louis City',
#                         'national': False},
#                'venue': {'address': '2100 Market Street',
#                          'capacity': 22500,
#                          'city': 'St. Louis, Missouri',
#                          'id': 19408,
#                          'image': 'https://media.api-sports.io/football/venues/19408.png',
#                          'name': 'CITYPARK',
#                          'surface': 'grass'}}],
#  'results': 29}

# %%
teams_df = pd.DataFrame(teams_response['response'])
teams_df.head()
# Out:
#                                                 team  \
# 0  {'id': 1595, 'name': 'Seattle Sounders', 'code...
# 1  {'id': 1596, 'name': 'San Jose Earthquakes', '...
# 2  {'id': 1597, 'name': 'FC Dallas', 'code': 'DAL...
# 3  {'id': 1598, 'name': 'Orlando City SC', 'code'...
# 4  {'id': 1599, 'name': 'Philadelphia Union', 'co...
#
#                                                venue
# 0  {'id': 11534, 'name': 'Lumen Field', 'address'...
# 1  {'id': 11918, 'name': 'PayPal Park', 'address'...
# 2  {'id': 1612, 'name': 'Toyota Stadium', 'addres...
# 3  {'id': 20500, 'name': 'Inter&Co Stadium', 'add...
# 4  {'id': 20745, 'name': 'Ukrainian American Spor...

# %% [markdown]
# #### Teams Data Cleaning

# %%
teams_df_final, venues_df_final = mls.clean('teams', teams_df)
display(teams_df_final.head(3))
display(venues_df_final.head(3))
# Out:
#      id                  name code country  founded  national  \
# 0  1595      Seattle Sounders  SEA     USA   2007.0     False
# 1  1596  San Jose Earthquakes  JOS     USA   1995.0     False
# 2  1597             FC Dallas  DAL     USA   1996.0     False
#
#                                                 logo  venue_id
# 0  https://media.api-sports.io/football/teams/159...     11534
# 1  https://media.api-sports.io/football/teams/159...     11918
# 2  https://media.api-sports.io/football/teams/159...      1612
#       id            name                      address                  city  \
# 0  11534     Lumen Field  800 Occidental Avenue South   Seattle, Washington
# 1  11918     PayPal Park          1123 Coleman Avenue  San Jose, California
# 2   1612  Toyota Stadium             6000 Main Street         Frisco, Texas
#
#    capacity          surface  \
# 0     72000  artificial turf
# 1     18000            grass
# 2     22565            grass
#
#                                                image  team_id
# 0  https://media.api-sports.io/football/venues/11...     1595
# 1  https://media.api-sports.io/football/venues/11...     1596
# 2  https://media.api-sports.io/football/venues/16...     1597

# %% [markdown]
# ### Games

# %%
games_payload = {'league':'253', 'season':'2024'}
games_response = mls.request(games_payload, 'fixtures')
pprint(games_response)
# Out:
# {'errors': [],
#  'get': 'fixtures',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'league': '253', 'season': '2024'},
#  'response': [{'fixture': {'date': '2024-02-22T01:00:00+00:00',
#                            'id': 1150754,
#                            'periods': {'first': 1708563600,
#                                        'second': 1708567200},
#                            'referee': 'Cristian Campo',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708563600,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Fort Lauderdale, Florida',
#                                      'id': 20764,
#                                      'name': 'Chase Stadium'}},
#                'goals': {'away': 0, 'home': 2},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 2},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1606,
#                                   'logo': 'https://media.api-sports.io/football/teams/1606.png',
#                                   'name': 'Real Salt Lake',
#                                   'winner': False},
#                          'home': {'id': 9568,
#                                   'logo': 'https://media.api-sports.io/football/teams/9568.png',
#                                   'name': 'Inter Miami',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-24T19:00:00+00:00',
#                            'id': 1150755,
#                            'periods': {'first': 1708801200,
#                                        'second': 1708804800},
#                            'referee': 'R. Bonilla',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708801200,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Columbus, Ohio',
#                                      'id': 12667,
#                                      'name': 'Lower.com Field'}},
#                'goals': {'away': 0, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 1},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1608,
#                                   'logo': 'https://media.api-sports.io/football/teams/1608.png',
#                                   'name': 'Atlanta United FC',
#                                   'winner': False},
#                          'home': {'id': 1613,
#                                   'logo': 'https://media.api-sports.io/football/teams/1613.png',
#                                   'name': 'Columbus Crew',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-24T21:30:00+00:00',
#                            'id': 1150756,
#                            'periods': {'first': 1708810200,
#                                        'second': 1708813800},
#                            'referee': 'W. Costa',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708810200,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Los Angeles, California',
#                                      'id': 19419,
#                                      'name': 'BMO Stadium'}},
#                'goals': {'away': 1, 'home': 2},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 2},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1595,
#                                   'logo': 'https://media.api-sports.io/football/teams/1595.png',
#                                   'name': 'Seattle Sounders',
#                                   'winner': False},
#                          'home': {'id': 1616,
#                                   'logo': 'https://media.api-sports.io/football/teams/1616.png',
#                                   'name': 'Los Angeles FC',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-25T00:30:00+00:00',
#                            'id': 1150757,
#                            'periods': {'first': 1708821000,
#                                        'second': 1708824600},
#                            'referee': 'M. Maric',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708821000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Charlotte, North Carolina',
#                                      'id': 18659,
#                                      'name': 'Bank of America Stadium'}},
#                'goals': {'away': 0, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 1},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1604,
#                                   'logo': 'https://media.api-sports.io/football/teams/1604.png',
#                                   'name': 'New York City FC',
#                                   'winner': False},
#                          'home': {'id': 18310,
#                                   'logo': 'https://media.api-sports.io/football/teams/18310.png',
#                                   'name': 'Charlotte',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-25T00:30:00+00:00',
#                            'id': 1150758,
#                            'periods': {'first': 1708821000,
#                                        'second': 1708824600},
#                            'referee': 'A. Musashe',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708821000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Washington, District of Columbia',
#                                      'id': 1613,
#                                      'name': 'Audi Field'}},
#                'goals': {'away': 1, 'home': 3},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 3},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1609,
#                                   'logo': 'https://media.api-sports.io/football/teams/1609.png',
#                                   'name': 'New England Revolution',
#                                   'winner': False},
#                          'home': {'id': 1615,
#                                   'logo': 'https://media.api-sports.io/football/teams/1615.png',
#                                   'name': 'DC United',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-25T00:30:00+00:00',
#                            'id': 1150759,
#                            'periods': {'first': 1708821000,
#                                        'second': 1708824600},
#                            'referee': 'R. Santos',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708821000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Orlando, Florida',
#                                      'id': 20500,
#                                      'name': 'Inter&Co Stadium'}},
#                'goals': {'away': 0, 'home': 0},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 0},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1614,
#                                   'logo': 'https://media.api-sports.io/football/teams/1614.png',
#                                   'name': 'Montreal Impact',
#                                   'winner': None},
#                          'home': {'id': 1598,
#                                   'logo': 'https://media.api-sports.io/football/teams/1598.png',
#                                   'name': 'Orlando City SC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-25T00:30:00+00:00',
#                            'id': 1150760,
#                            'periods': {'first': 1708821000,
#                                        'second': 1708824600},
#                            'referee': 'M. Hassan',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708821000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Chester, Pennsylvania',
#                                      'id': 1620,
#                                      'name': 'Subaru Park'}},
#                'goals': {'away': 2, 'home': 2},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 2, 'home': 2},
#                          'halftime': {'away': 1, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1607,
#                                   'logo': 'https://media.api-sports.io/football/teams/1607.png',
#                                   'name': 'Chicago Fire',
#                                   'winner': None},
#                          'home': {'id': 1599,
#                                   'logo': 'https://media.api-sports.io/football/teams/1599.png',
#                                   'name': 'Philadelphia Union',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-25T01:30:00+00:00',
#                            'id': 1150761,
#                            'periods': {'first': 1708824600,
#                                        'second': 1708828200},
#                            'referee': 'T. Wiseman',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708824600,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Austin, Texas',
#                                      'id': 11535,
#                                      'name': 'Q2 Stadium'}},
#                'goals': {'away': 2, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 2, 'home': 1},
#                          'halftime': {'away': 1, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1612,
#                                   'logo': 'https://media.api-sports.io/football/teams/1612.png',
#                                   'name': 'Minnesota United FC',
#                                   'winner': True},
#                          'home': {'id': 16489,
#                                   'logo': 'https://media.api-sports.io/football/teams/16489.png',
#                                   'name': 'Austin',
#                                   'winner': False}}},
#               {'fixture': {'date': '2024-02-25T01:30:00+00:00',
#                            'id': 1150762,
#                            'periods': {'first': 1708824600,
#                                        'second': 1708828200},
#                            'referee': 'D. Beard',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708824600,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Frisco, Texas',
#                                      'id': 1612,
#                                      'name': 'Toyota Stadium'}},
#                'goals': {'away': 1, 'home': 2},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 2},
#                          'halftime': {'away': 1, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1596,
#                                   'logo': 'https://media.api-sports.io/football/teams/1596.png',
#                                   'name': 'San Jose Earthquakes',
#                                   'winner': False},
#                          'home': {'id': 1597,
#                                   'logo': 'https://media.api-sports.io/football/teams/1597.png',
#                                   'name': 'FC Dallas',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-25T01:30:00+00:00',
#                            'id': 1150763,
#                            'periods': {'first': 1708824600,
#                                        'second': 1708828200},
#                            'referee': 'J. Herrera',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708824600,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Houston, Texas',
#                                      'id': 19418,
#                                      'name': 'Shell Energy Stadium'}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1611,
#                                   'logo': 'https://media.api-sports.io/football/teams/1611.png',
#                                   'name': 'Sporting Kansas City',
#                                   'winner': None},
#                          'home': {'id': 1600,
#                                   'logo': 'https://media.api-sports.io/football/teams/1600.png',
#                                   'name': 'Houston Dynamo',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-25T01:30:00+00:00',
#                            'id': 1150764,
#                            'periods': {'first': 1708824600,
#                                        'second': 1708828200},
#                            'referee': 'L. Hernandez',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708824600,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'St. Louis, Missouri',
#                                      'id': 19408,
#                                      'name': 'CITYPARK'}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 1',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1606,
#                                   'logo': 'https://media.api-sports.io/football/teams/1606.png',
#                                   'name': 'Real Salt Lake',
#                                   'winner': None},
#                          'home': {'id': 20787,
#                                   'logo': 'https://media.api-sports.io/football/teams/20787.png',
#                                   'name': 'St. Louis City',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-25T03:30:00+00:00',
#                            'id': 1150765,
#                            'periods': {'first': 1708831800,
#                                        'second': 1708835400},
#                            'referee': 'A. Zhelyazkov',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708831800,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Portland, Oregon',
#                                      'id': 1748,
#                                      'name': 'Providence Park'}},
#                'goals': {'away': 1, 'home': 4},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 4},
#                          'halftime': {'away': 0, 'home': 4},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1610,
#                                   'logo': 'https://media.api-sports.io/football/teams/1610.png',
#                                   'name': 'Colorado Rapids',
#                                   'winner': False},
#                          'home': {'id': 1617,
#                                   'logo': 'https://media.api-sports.io/football/teams/1617.png',
#                                   'name': 'Portland Timbers',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-02-25T19:30:00+00:00',
#                            'id': 1150766,
#                            'periods': {'first': 1708889400,
#                                        'second': 1708893000},
#                            'referee': 'J. Weiner',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708889400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Cincinnati, Ohio',
#                                      'id': 19229,
#                                      'name': 'TQL Stadium'}},
#                'goals': {'away': 0, 'home': 0},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 0},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1601,
#                                   'logo': 'https://media.api-sports.io/football/teams/1601.png',
#                                   'name': 'Toronto FC',
#                                   'winner': None},
#                          'home': {'id': 2242,
#                                   'logo': 'https://media.api-sports.io/football/teams/2242.png',
#                                   'name': 'FC Cincinnati',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-25T22:00:00+00:00',
#                            'id': 1150767,
#                            'periods': {'first': 1708898400,
#                                        'second': 1708902000},
#                            'referee': 'Cristian Campo',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708898400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Nashville, Tennessee',
#                                      'id': 19357,
#                                      'name': 'GEODIS Park'}},
#                'goals': {'away': 0, 'home': 0},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 0},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1602,
#                                   'logo': 'https://media.api-sports.io/football/teams/1602.png',
#                                   'name': 'New York Red Bulls',
#                                   'winner': None},
#                          'home': {'id': 9569,
#                                   'logo': 'https://media.api-sports.io/football/teams/9569.png',
#                                   'name': 'Nashville SC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-02-26T02:00:00+00:00',
#                            'id': 1150768,
#                            'periods': {'first': 1708912800,
#                                        'second': 1708916400},
#                            'referee': 'G. Ciampi',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1708912800,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Carson, California',
#                                      'id': 1616,
#                                      'name': 'Dignity Health Sports Park'}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 9568,
#                                   'logo': 'https://media.api-sports.io/football/teams/9568.png',
#                                   'name': 'Inter Miami',
#                                   'winner': None},
#                          'home': {'id': 1605,
#                                   'logo': 'https://media.api-sports.io/football/teams/1605.png',
#                                   'name': 'Los Angeles Galaxy',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-03-03T00:30:00+00:00',
#                            'id': 1150769,
#                            'periods': {'first': 1709425800,
#                                        'second': 1709429400},
#                            'referee': 'S. Bowman',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709425800,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Vancouver, British Columbia',
#                                      'id': 19445,
#                                      'name': 'BC Place'}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 1, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 18310,
#                                   'logo': 'https://media.api-sports.io/football/teams/18310.png',
#                                   'name': 'Charlotte',
#                                   'winner': None},
#                          'home': {'id': 1603,
#                                   'logo': 'https://media.api-sports.io/football/teams/1603.png',
#                                   'name': 'Vancouver Whitecaps',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-03-02T19:00:00+00:00',
#                            'id': 1150770,
#                            'periods': {'first': 1709406000,
#                                        'second': 1709409600},
#                            'referee': 'A. Hadzic',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709406000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Saint Paul, Minnesota',
#                                      'id': 1617,
#                                      'name': 'Allianz Field'}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 0, 'home': 0},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1613,
#                                   'logo': 'https://media.api-sports.io/football/teams/1613.png',
#                                   'name': 'Columbus Crew',
#                                   'winner': None},
#                          'home': {'id': 1612,
#                                   'logo': 'https://media.api-sports.io/football/teams/1612.png',
#                                   'name': 'Minnesota United FC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-03-02T19:00:00+00:00',
#                            'id': 1150771,
#                            'periods': {'first': 1709406000,
#                                        'second': 1709409600},
#                            'referee': 'A. Zhelyazkov',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709406000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Sandy, Utah',
#                                      'id': 19223,
#                                      'name': 'America First Field'}},
#                'goals': {'away': 0, 'home': 3},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 3},
#                          'halftime': {'away': 0, 'home': 3},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1616,
#                                   'logo': 'https://media.api-sports.io/football/teams/1616.png',
#                                   'name': 'Los Angeles FC',
#                                   'winner': False},
#                          'home': {'id': 1606,
#                                   'logo': 'https://media.api-sports.io/football/teams/1606.png',
#                                   'name': 'Real Salt Lake',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-03-02T21:30:00+00:00',
#                            'id': 1150772,
#                            'periods': {'first': 1709415000,
#                                        'second': 1709418600},
#                            'referee': 'J. Herrera',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709415000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Fort Lauderdale, Florida',
#                                      'id': 20764,
#                                      'name': 'Chase Stadium'}},
#                'goals': {'away': 0, 'home': 5},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 2',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 5},
#                          'halftime': {'away': 0, 'home': 3},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1598,
#                                   'logo': 'https://media.api-sports.io/football/teams/1598.png',
#                                   'name': 'Orlando City SC',
#                                   'winner': False},
#                          'home': {'id': 9568,
#                                   'logo': 'https://media.api-sports.io/football/teams/9568.png',
#                                   'name': 'Inter Miami',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-03-03T01:30:00+00:00',
#                            'id': 1150773,
#                            'periods': {'first': 1709429400,
#                                        'second': 1709433000},
#                            'referee': 'M. Maric',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709429400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Chicago, Illinois',
#                                      'id': 1609,
#                                      'name': 'Soldier Field'}},
#                'goals': {'away': 2, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 3',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 2, 'home': 1},
#                          'halftime': {'away': 1, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 2242,
#                                   'logo': 'https://media.api-sports.io/football/teams/2242.png',
#                                   'name': 'FC Cincinnati',
#                                   'winner': True},
#                          'home': {'id': 1607,
#                                   'logo': 'https://media.api-sports.io/football/teams/1607.png',
#                                   'name': 'Chicago Fire',
#                                   'winner': False}}},
#               {'fixture': {'date': '2024-03-03T01:30:00+00:00',
#                            'id': 1150774,
#                            'periods': {'first': 1709429400,
#                                        'second': 1709433000},
#                            'referee': 'K. Johnston',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709429400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Frisco, Texas',
#                                      'id': 1612,
#                                      'name': 'Toyota Stadium'}},
#                'goals': {'away': 2, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 3',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 2, 'home': 1},
#                          'halftime': {'away': 1, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1614,
#                                   'logo': 'https://media.api-sports.io/football/teams/1614.png',
#                                   'name': 'Montreal Impact',
#                                   'winner': True},
#                          'home': {'id': 1597,
#                                   'logo': 'https://media.api-sports.io/football/teams/1597.png',
#                                   'name': 'FC Dallas',
#                                   'winner': False}}},
#               {'fixture': {'date': '2024-03-03T01:30:00+00:00',
#                            'id': 1150775,
#                            'periods': {'first': 1709429400,
#                                        'second': 1709433000},
#                            'referee': 'L. Hernandez',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709429400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Houston, Texas',
#                                      'id': 19418,
#                                      'name': 'Shell Energy Stadium'}},
#                'goals': {'away': 2, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 3',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 2, 'home': 1},
#                          'halftime': {'away': 1, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1602,
#                                   'logo': 'https://media.api-sports.io/football/teams/1602.png',
#                                   'name': 'New York Red Bulls',
#                                   'winner': True},
#                          'home': {'id': 1600,
#                                   'logo': 'https://media.api-sports.io/football/teams/1600.png',
#                                   'name': 'Houston Dynamo',
#                                   'winner': False}}},
#               {'fixture': {'date': '2024-03-03T01:30:00+00:00',
#                            'id': 1150776,
#                            'periods': {'first': 1709429400,
#                                        'second': 1709433000},
#                            'referee': 'R. Bonilla',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709429400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Kansas City, Kansas',
#                                      'id': 1615,
#                                      'name': "Children's Mercy Park"}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 3',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 1, 'home': 1},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1599,
#                                   'logo': 'https://media.api-sports.io/football/teams/1599.png',
#                                   'name': 'Philadelphia Union',
#                                   'winner': None},
#                          'home': {'id': 1611,
#                                   'logo': 'https://media.api-sports.io/football/teams/1611.png',
#                                   'name': 'Sporting Kansas City',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-03-03T01:30:00+00:00',
#                            'id': 1150777,
#                            'periods': {'first': 1709429400,
#                                        'second': 1709433000},
#                            'referee': 'E. Lezama',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709429400,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'St. Louis, Missouri',
#                                      'id': 19408,
#                                      'name': 'CITYPARK'}},
#                'goals': {'away': 0, 'home': 2},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 3',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': 0, 'home': 2},
#                          'halftime': {'away': 0, 'home': 1},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1604,
#                                   'logo': 'https://media.api-sports.io/football/teams/1604.png',
#                                   'name': 'New York City FC',
#                                   'winner': False},
#                          'home': {'id': 20787,
#                                   'logo': 'https://media.api-sports.io/football/teams/20787.png',
#                                   'name': 'St. Louis City',
#                                   'winner': True}}},
#               {'fixture': {'date': '2024-03-03T02:30:00+00:00',
#                            'id': 1150778,
#                            'periods': {'first': 1709433000,
#                                        'second': 1709436600},
#                            'referee': 'E. Rosano',
#                            'status': {'elapsed': 90,
#                                       'long': 'Match Finished',
#                                       'short': 'FT'},
#                            'timestamp': 1709433000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Commerce City, Colorado',
#                                      'id': 1610,
#                                      'name': "Dick's Sporting Goods Park"}},
#                'goals': {'away': 1, 'home': 1},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
# ...
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1608,
#                                   'logo': 'https://media.api-sports.io/football/teams/1608.png',
#                                   'name': 'Atlanta United FC',
#                                   'winner': None},
#                          'home': {'id': 1598,
#                                   'logo': 'https://media.api-sports.io/football/teams/1598.png',
#                                   'name': 'Orlando City SC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-19T22:00:00+00:00',
#                            'id': 1151239,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729375200,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Chester, Pennsylvania',
#                                      'id': 1620,
#                                      'name': 'Subaru Park'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 2242,
#                                   'logo': 'https://media.api-sports.io/football/teams/2242.png',
#                                   'name': 'FC Cincinnati',
#                                   'winner': None},
#                          'home': {'id': 1599,
#                                   'logo': 'https://media.api-sports.io/football/teams/1599.png',
#                                   'name': 'Philadelphia Union',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151240,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Austin, Texas',
#                                      'id': 11535,
#                                      'name': 'Q2 Stadium'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1610,
#                                   'logo': 'https://media.api-sports.io/football/teams/1610.png',
#                                   'name': 'Colorado Rapids',
#                                   'winner': None},
#                          'home': {'id': 16489,
#                                   'logo': 'https://media.api-sports.io/football/teams/16489.png',
#                                   'name': 'Austin',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151241,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Frisco, Texas',
#                                      'id': 1612,
#                                      'name': 'Toyota Stadium'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1611,
#                                   'logo': 'https://media.api-sports.io/football/teams/1611.png',
#                                   'name': 'Sporting Kansas City',
#                                   'winner': None},
#                          'home': {'id': 1597,
#                                   'logo': 'https://media.api-sports.io/football/teams/1597.png',
#                                   'name': 'FC Dallas',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151242,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Houston, Texas',
#                                      'id': 19418,
#                                      'name': 'Shell Energy Stadium'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1605,
#                                   'logo': 'https://media.api-sports.io/football/teams/1605.png',
#                                   'name': 'Los Angeles Galaxy',
#                                   'winner': None},
#                          'home': {'id': 1600,
#                                   'logo': 'https://media.api-sports.io/football/teams/1600.png',
#                                   'name': 'Houston Dynamo',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151243,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Los Angeles, California',
#                                      'id': 19419,
#                                      'name': 'BMO Stadium'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1596,
#                                   'logo': 'https://media.api-sports.io/football/teams/1596.png',
#                                   'name': 'San Jose Earthquakes',
#                                   'winner': None},
#                          'home': {'id': 1616,
#                                   'logo': 'https://media.api-sports.io/football/teams/1616.png',
#                                   'name': 'Los Angeles FC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151244,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Saint Paul, Minnesota',
#                                      'id': 1617,
#                                      'name': 'Allianz Field'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 20787,
#                                   'logo': 'https://media.api-sports.io/football/teams/20787.png',
#                                   'name': 'St. Louis City',
#                                   'winner': None},
#                          'home': {'id': 1612,
#                                   'logo': 'https://media.api-sports.io/football/teams/1612.png',
#                                   'name': 'Minnesota United FC',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151245,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Sandy, Utah',
#                                      'id': 19223,
#                                      'name': 'America First Field'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1603,
#                                   'logo': 'https://media.api-sports.io/football/teams/1603.png',
#                                   'name': 'Vancouver Whitecaps',
#                                   'winner': None},
#                          'home': {'id': 1606,
#                                   'logo': 'https://media.api-sports.io/football/teams/1606.png',
#                                   'name': 'Real Salt Lake',
#                                   'winner': None}}},
#               {'fixture': {'date': '2024-10-20T01:00:00+00:00',
#                            'id': 1151246,
#                            'periods': {'first': None, 'second': None},
#                            'referee': None,
#                            'status': {'elapsed': None,
#                                       'long': 'Not Started',
#                                       'short': 'NS'},
#                            'timestamp': 1729386000,
#                            'timezone': 'UTC',
#                            'venue': {'city': 'Seattle, Washington',
#                                      'id': 11534,
#                                      'name': 'Lumen Field'}},
#                'goals': {'away': None, 'home': None},
#                'league': {'country': 'USA',
#                           'flag': 'https://media.api-sports.io/flags/us.svg',
#                           'id': 253,
#                           'logo': 'https://media.api-sports.io/football/leagues/253.png',
#                           'name': 'Major League Soccer',
#                           'round': 'Regular Season - 48',
#                           'season': 2024},
#                'score': {'extratime': {'away': None, 'home': None},
#                          'fulltime': {'away': None, 'home': None},
#                          'halftime': {'away': None, 'home': None},
#                          'penalty': {'away': None, 'home': None}},
#                'teams': {'away': {'id': 1617,
#                                   'logo': 'https://media.api-sports.io/football/teams/1617.png',
#                                   'name': 'Portland Timbers',
#                                   'winner': None},
#                          'home': {'id': 1595,
#                                   'logo': 'https://media.api-sports.io/football/teams/1595.png',
#                                   'name': 'Seattle Sounders',
#                                   'winner': None}}}],
#  'results': 493}

# %%
games_df = pd.DataFrame(games_response['response'])
print(len(games_df))
games_df.head(1)
# Out:
# 493
#                                              fixture  \
# 0  {'id': 1150754, 'referee': 'Cristian Campo', '...
#
#                                               league  \
# 0  {'id': 253, 'name': 'Major League Soccer', 'co...
#
#                                                teams                   goals  \
# 0  {'home': {'id': 9568, 'name': 'Inter Miami', '...  {'home': 2, 'away': 0}
#
#                                                score
# 0  {'halftime': {'home': 1, 'away': 0}, 'fulltime...

# %% [markdown]
# #### Games Data Cleaning

# %%
games_df_final = mls.clean('games', games_df)
games_df_final.head()
# Out:
#         id        date   timestamp                  datetime timezone  \
# 0  1150754  2024-02-22  1708563600 2024-02-22 01:00:00+00:00      UTC
# 1  1150755  2024-02-24  1708801200 2024-02-24 19:00:00+00:00      UTC
# 2  1150756  2024-02-24  1708810200 2024-02-24 21:30:00+00:00      UTC
# 3  1150757  2024-02-25  1708821000 2024-02-25 00:30:00+00:00      UTC
# 4  1150758  2024-02-25  1708821000 2024-02-25 00:30:00+00:00      UTC
#
#    venue_id status  league_id          league_name country_name  home_id  \
# 0   20764.0     FT        253  Major League Soccer          USA     9568
# 1   12667.0     FT        253  Major League Soccer          USA     1613
# 2   19419.0     FT        253  Major League Soccer          USA     1616
# 3   18659.0     FT        253  Major League Soccer          USA    18310
# 4    1613.0     FT        253  Major League Soccer          USA     1615
#
#         home_name home_winner  away_id               away_name away_winner  \
# 0     Inter Miami        True     1606          Real Salt Lake       False
# 1   Columbus Crew        True     1608       Atlanta United FC       False
# 2  Los Angeles FC        True     1595        Seattle Sounders       False
# 3       Charlotte        True     1604        New York City FC       False
# 4       DC United        True     1609  New England Revolution       False
#
#    home_total  away_total
# 0         2.0         0.0
# 1         1.0         0.0
# 2         2.0         1.0
# 3         1.0         0.0
# 4         3.0         1.0

# %% [markdown]
# ### DB Connection

# %%
# create postgresql connection
from sqlalchemy import create_engine
from creds import postgresql_pw

engine = create_engine(f'postgresql+psycopg2://postgres:{postgresql_pw}@localhost:5432/api_sports')

# import teams_df and games_df to new tables in api-sports db
teams_df_final.to_sql('mls_teams', con=engine, if_exists='replace', index=False)
venues_df_final.to_sql('mls_venues', con=engine, if_exists='replace', index=False)
games_df_final.to_sql('mls_games', con=engine, if_exists='replace', index=False)
# Out:
# 493
